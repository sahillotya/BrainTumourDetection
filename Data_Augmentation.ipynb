# %% [markdown]
# # Data Augmentation

# %% [markdown]
# **About the data:** <br>
# The dataset contains 2 folders: yes and no which contains 253 Brain MRI Images. The folder yes contains 155 Brain MRI Images that are tumorous and the folder no contains 98 Brain MRI Images that are non-tumorous. You can find [here](https://www.kaggle.com/navoneel/brain-mri-images-for-brain-tumor-detection).

# %% [markdown]
# Since this is a small dataset, I used data augmentation in order to create more images.

# %%
from keras.preprocessing.image import ImageDataGenerator
import cv2
import imutils
import matplotlib.pyplot as plt
from os import listdir
import time    

# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
# Nicely formatted time string
def hms_string(sec_elapsed):
    h = int(sec_elapsed / (60 * 60))
    m = int((sec_elapsed % (60 * 60)) / 60)
    s = sec_elapsed % 60
    return f"{h}:{m}:{round(s,1)}"

# %%
def augment_data(file_dir, n_generated_samples, save_to_dir):
    
    data_gen = ImageDataGenerator(rotation_range=10, 
                                  width_shift_range=0.1, 
                                  height_shift_range=0.1, 
                                  shear_range=0.1, 
                                  brightness_range=(0.3, 1.0),
                                  horizontal_flip=True, 
                                  vertical_flip=True, 
                                  fill_mode='nearest'
                                 )

    
    for filename in listdir(file_dir):
        print(file_dir+"/"+filename)
        # load the image
        image = cv2.imread(file_dir + '/' + filename)
        # reshape the image
        image = image.reshape((1,)+image.shape)
        # prefix of the names for the generated sampels.
        save_prefix = 'aug_' + filename[:-4]
        # generate 'n_generated_samples' sample images
        i=0
        for batch in data_gen.flow(x=image, batch_size=1, save_to_dir=save_to_dir, 
                                           save_prefix=save_prefix, save_format='jpg'):
            i += 1
            if i > n_generated_samples:
                break

# %%
start_time = time.time()

augmented_data_path = '/content/drive/My Drive/MRI_Data/augmented_data/'
yes_path="/content/drive/My Drive/MRI_Data/yes"
no_path="/content/drive/My Drive/MRI_Data/no"

# augment data for the examples with label equal to 'yes' representing tumurous examples
augment_data(file_dir=yes_path, n_generated_samples=6, save_to_dir=augmented_data_path+'yes')
# augment data for the examples with label equal to 'no' representing non-tumurous examples
augment_data(file_dir=no_path, n_generated_samples=9, save_to_dir=augmented_data_path+'no')

end_time = time.time()
execution_time = (end_time - start_time)
print(f"Elapsed time: {hms_string(execution_time)}")
# Out:
# /content/drive/My Drive/MRI_Data/yes/Y148.JPG
# /content/drive/My Drive/MRI_Data/yes/Y153.jpg
# /content/drive/My Drive/MRI_Data/yes/Y15.jpg
# /content/drive/My Drive/MRI_Data/yes/Y154.jpg
# /content/drive/My Drive/MRI_Data/yes/Y14.jpg
# /content/drive/My Drive/MRI_Data/yes/Y146.JPG
# /content/drive/My Drive/MRI_Data/yes/Y147.JPG
# /content/drive/My Drive/MRI_Data/yes/Y120.JPG
# /content/drive/My Drive/MRI_Data/yes/Y13.jpg
# /content/drive/My Drive/MRI_Data/yes/Y12.jpg
# /content/drive/My Drive/MRI_Data/yes/Y113.JPG
# /content/drive/My Drive/MRI_Data/yes/Y114.JPG
# /content/drive/My Drive/MRI_Data/yes/Y116.JPG
# /content/drive/My Drive/MRI_Data/yes/Y115.JPG
# /content/drive/My Drive/MRI_Data/yes/Y117.JPG
# /content/drive/My Drive/MRI_Data/yes/Y11.jpg
# /content/drive/My Drive/MRI_Data/yes/Y111.JPG
# /content/drive/My Drive/MRI_Data/yes/Y112.JPG
# /content/drive/My Drive/MRI_Data/yes/Y109.JPG
# /content/drive/My Drive/MRI_Data/yes/Y108.jpg
# /content/drive/My Drive/MRI_Data/yes/Y105.jpg
# /content/drive/My Drive/MRI_Data/yes/Y106.jpg
# /content/drive/My Drive/MRI_Data/yes/Y107.jpg
# /content/drive/My Drive/MRI_Data/yes/Y103.jpg
# /content/drive/My Drive/MRI_Data/yes/Y100.JPG
# /content/drive/My Drive/MRI_Data/yes/Y101.jpg
# /content/drive/My Drive/MRI_Data/yes/Y102.jpg
# /content/drive/My Drive/MRI_Data/yes/Y104.jpg
# /content/drive/My Drive/MRI_Data/yes/Y10.jpg
# /content/drive/My Drive/MRI_Data/yes/Y1.jpg
# /content/drive/My Drive/MRI_Data/yes/Y244.JPG
# /content/drive/My Drive/MRI_Data/yes/Y195.JPG
# /content/drive/My Drive/MRI_Data/yes/Y194.jpg
# /content/drive/My Drive/MRI_Data/yes/Y185.jpg
# /content/drive/My Drive/MRI_Data/yes/Y188.jpg
# /content/drive/My Drive/MRI_Data/yes/Y186.jpg
# /content/drive/My Drive/MRI_Data/yes/Y192.JPG
# /content/drive/My Drive/MRI_Data/yes/Y19.JPG
# /content/drive/My Drive/MRI_Data/yes/Y187.jpg
# /content/drive/My Drive/MRI_Data/yes/Y183.jpg
# /content/drive/My Drive/MRI_Data/yes/Y184.JPG
# /content/drive/My Drive/MRI_Data/yes/Y193.JPG
# /content/drive/My Drive/MRI_Data/yes/Y182.JPG
# /content/drive/My Drive/MRI_Data/yes/Y181.jpg
# /content/drive/My Drive/MRI_Data/yes/Y17.jpg
# /content/drive/My Drive/MRI_Data/yes/Y169.jpg
# /content/drive/My Drive/MRI_Data/yes/Y170.JPG
# /content/drive/My Drive/MRI_Data/yes/Y18.JPG
# /content/drive/My Drive/MRI_Data/yes/Y168.jpg
# /content/drive/My Drive/MRI_Data/yes/Y166.JPG
# /content/drive/My Drive/MRI_Data/yes/Y165.JPG
# /content/drive/My Drive/MRI_Data/yes/Y167.JPG
# /content/drive/My Drive/MRI_Data/yes/Y180.jpg
# /content/drive/My Drive/MRI_Data/yes/Y164.JPG
# /content/drive/My Drive/MRI_Data/yes/Y159.JPG
# /content/drive/My Drive/MRI_Data/yes/Y160.JPG
# /content/drive/My Drive/MRI_Data/yes/Y161.JPG
# /content/drive/My Drive/MRI_Data/yes/Y162.jpg
# /content/drive/My Drive/MRI_Data/yes/Y163.JPG
# /content/drive/My Drive/MRI_Data/yes/Y16.JPG
# /content/drive/My Drive/MRI_Data/yes/Y157.JPG
# /content/drive/My Drive/MRI_Data/yes/Y158.JPG
# /content/drive/My Drive/MRI_Data/yes/Y156.JPG
# /content/drive/My Drive/MRI_Data/yes/Y155.JPG
# /content/drive/My Drive/MRI_Data/yes/Y42.jpg
# /content/drive/My Drive/MRI_Data/yes/Y4.jpg
# /content/drive/My Drive/MRI_Data/yes/Y40.JPG
# /content/drive/My Drive/MRI_Data/yes/Y38.jpg
# /content/drive/My Drive/MRI_Data/yes/Y39.jpg
# /content/drive/My Drive/MRI_Data/yes/Y37.jpg
# /content/drive/My Drive/MRI_Data/yes/Y41.jpg
# /content/drive/My Drive/MRI_Data/yes/Y35.jpg
# /content/drive/My Drive/MRI_Data/yes/Y36.JPG
# /content/drive/My Drive/MRI_Data/yes/Y34.jpg
# /content/drive/My Drive/MRI_Data/yes/Y33.jpg
# /content/drive/My Drive/MRI_Data/yes/Y32.jpg
# /content/drive/My Drive/MRI_Data/yes/Y28.jpg
# /content/drive/My Drive/MRI_Data/yes/Y29.jpg
# /content/drive/My Drive/MRI_Data/yes/Y3.jpg
# /content/drive/My Drive/MRI_Data/yes/Y30.jpg
# /content/drive/My Drive/MRI_Data/yes/Y259.JPG
# /content/drive/My Drive/MRI_Data/yes/Y26.jpg
# /content/drive/My Drive/MRI_Data/yes/Y27.jpg
# /content/drive/My Drive/MRI_Data/yes/Y258.JPG
# /content/drive/My Drive/MRI_Data/yes/Y31.jpg
# /content/drive/My Drive/MRI_Data/yes/Y257.jpg
# /content/drive/My Drive/MRI_Data/yes/Y256.JPG
# /content/drive/My Drive/MRI_Data/yes/Y250.jpg
# /content/drive/My Drive/MRI_Data/yes/Y251.JPG
# /content/drive/My Drive/MRI_Data/yes/Y252.jpg
# /content/drive/My Drive/MRI_Data/yes/Y253.JPG
# /content/drive/My Drive/MRI_Data/yes/Y254.jpg
# /content/drive/My Drive/MRI_Data/yes/Y255.JPG
# /content/drive/My Drive/MRI_Data/yes/Y248.JPG
# /content/drive/My Drive/MRI_Data/yes/Y249.JPG
# /content/drive/My Drive/MRI_Data/yes/Y25.jpg
# /content/drive/My Drive/MRI_Data/yes/Y247.JPG
# /content/drive/My Drive/MRI_Data/yes/Y246.JPG
# /content/drive/My Drive/MRI_Data/yes/Y24.jpg
# /content/drive/My Drive/MRI_Data/yes/Y22.jpg
# /content/drive/My Drive/MRI_Data/yes/Y23.JPG
# /content/drive/My Drive/MRI_Data/yes/Y242.JPG
# /content/drive/My Drive/MRI_Data/yes/Y243.JPG
# /content/drive/My Drive/MRI_Data/yes/Y245.jpg
# /content/drive/My Drive/MRI_Data/yes/Y21.jpg
# /content/drive/My Drive/MRI_Data/yes/Y2.jpg
# /content/drive/My Drive/MRI_Data/yes/Y20.jpg
# /content/drive/My Drive/MRI_Data/yes/Y99.JPG
# /content/drive/My Drive/MRI_Data/yes/Y98.JPG
# /content/drive/My Drive/MRI_Data/yes/Y97.JPG
# /content/drive/My Drive/MRI_Data/yes/Y90.jpg
# /content/drive/My Drive/MRI_Data/yes/Y91.jpg
# /content/drive/My Drive/MRI_Data/yes/Y92.jpg
# /content/drive/My Drive/MRI_Data/yes/Y92.png
# /content/drive/My Drive/MRI_Data/yes/Y9.jpg
# /content/drive/My Drive/MRI_Data/yes/Y96.jpg
# /content/drive/My Drive/MRI_Data/yes/Y86.JPG
# /content/drive/My Drive/MRI_Data/yes/Y89.JPG
# /content/drive/My Drive/MRI_Data/yes/Y85.JPG
# /content/drive/My Drive/MRI_Data/yes/Y95.jpg
# /content/drive/My Drive/MRI_Data/yes/Y82.jpg
# /content/drive/My Drive/MRI_Data/yes/Y81.jpg
# /content/drive/My Drive/MRI_Data/yes/Y79.jpg
# /content/drive/My Drive/MRI_Data/yes/Y73.jpg
# /content/drive/My Drive/MRI_Data/yes/Y74.jpg
# /content/drive/My Drive/MRI_Data/yes/Y75.JPG
# /content/drive/My Drive/MRI_Data/yes/Y77.jpg
# /content/drive/My Drive/MRI_Data/yes/Y76.jpg
# /content/drive/My Drive/MRI_Data/yes/Y78.jpg
# /content/drive/My Drive/MRI_Data/yes/Y71.JPG
# /content/drive/My Drive/MRI_Data/yes/Y8.jpg
# /content/drive/My Drive/MRI_Data/yes/Y70.jpg
# /content/drive/My Drive/MRI_Data/yes/Y7.jpg
# /content/drive/My Drive/MRI_Data/yes/Y67.JPG
# /content/drive/My Drive/MRI_Data/yes/Y6.jpg
# /content/drive/My Drive/MRI_Data/yes/Y59.JPG
# /content/drive/My Drive/MRI_Data/yes/Y60.jpg
# /content/drive/My Drive/MRI_Data/yes/Y61.jpg
# /content/drive/My Drive/MRI_Data/yes/Y62.jpg
# /content/drive/My Drive/MRI_Data/yes/Y65.JPG
# /content/drive/My Drive/MRI_Data/yes/Y66.JPG
# /content/drive/My Drive/MRI_Data/yes/Y69.jpg
# /content/drive/My Drive/MRI_Data/yes/Y58.JPG
# /content/drive/My Drive/MRI_Data/yes/Y56.jpg
# /content/drive/My Drive/MRI_Data/yes/Y53.jpg
# /content/drive/My Drive/MRI_Data/yes/Y55.jpg
# /content/drive/My Drive/MRI_Data/yes/Y50.JPG
# /content/drive/My Drive/MRI_Data/yes/Y51.jpg
# /content/drive/My Drive/MRI_Data/yes/Y52.jpg
# /content/drive/My Drive/MRI_Data/yes/Y49.JPG
# /content/drive/My Drive/MRI_Data/yes/Y46.jpg
# /content/drive/My Drive/MRI_Data/yes/Y47.JPG
# /content/drive/My Drive/MRI_Data/yes/Y45.JPG
# /content/drive/My Drive/MRI_Data/yes/Y54.jpg
# /content/drive/My Drive/MRI_Data/yes/Y44.JPG
# /content/drive/My Drive/MRI_Data/no/31 no.jpg
# /content/drive/My Drive/MRI_Data/no/3 no.jpg
# /content/drive/My Drive/MRI_Data/no/30 no.jpg
# /content/drive/My Drive/MRI_Data/no/34 no.jpg
# /content/drive/My Drive/MRI_Data/no/32 no.jpg
# /content/drive/My Drive/MRI_Data/no/37 no.jpg
# /content/drive/My Drive/MRI_Data/no/29 no.jpg
# /content/drive/My Drive/MRI_Data/no/28 no.jpg
# /content/drive/My Drive/MRI_Data/no/26 no.jpg
# /content/drive/My Drive/MRI_Data/no/27 no.jpg
# /content/drive/My Drive/MRI_Data/no/21 no.jpg
# /content/drive/My Drive/MRI_Data/no/22 no.jpg
# /content/drive/My Drive/MRI_Data/no/25 no.jpg
# /content/drive/My Drive/MRI_Data/no/24 no.jpg
# /content/drive/My Drive/MRI_Data/no/23 no.jpg
# /content/drive/My Drive/MRI_Data/no/20 no.jpg
# /content/drive/My Drive/MRI_Data/no/19 no.jpg
# /content/drive/My Drive/MRI_Data/no/2 no.jpeg
# /content/drive/My Drive/MRI_Data/no/13 no.jpg
# /content/drive/My Drive/MRI_Data/no/11 no.jpg
# /content/drive/My Drive/MRI_Data/no/14 no.jpg
# /content/drive/My Drive/MRI_Data/no/15 no.jpg
# /content/drive/My Drive/MRI_Data/no/12 no.jpg
# /content/drive/My Drive/MRI_Data/no/18 no.jpg
# /content/drive/My Drive/MRI_Data/no/1 no.jpeg
# /content/drive/My Drive/MRI_Data/no/10 no.jpg
# /content/drive/My Drive/MRI_Data/no/17 no.jpg
# /content/drive/My Drive/MRI_Data/no/No19.jpg
# /content/drive/My Drive/MRI_Data/no/No21.jpg
# /content/drive/My Drive/MRI_Data/no/No22.jpg
# /content/drive/My Drive/MRI_Data/no/No20.jpg
# /content/drive/My Drive/MRI_Data/no/No17.jpg
# /content/drive/My Drive/MRI_Data/no/No18.jpg
# /content/drive/My Drive/MRI_Data/no/No16.jpg
# /content/drive/My Drive/MRI_Data/no/No15.jpg
# /content/drive/My Drive/MRI_Data/no/no.jpg
# /content/drive/My Drive/MRI_Data/no/No11.jpg
# /content/drive/My Drive/MRI_Data/no/No12.jpg
# /content/drive/My Drive/MRI_Data/no/No14.jpg
# /content/drive/My Drive/MRI_Data/no/no 98.jpg
# /content/drive/My Drive/MRI_Data/no/no 99.jpg
# /content/drive/My Drive/MRI_Data/no/no 97.jpg
# /content/drive/My Drive/MRI_Data/no/no 96.jpg
# /content/drive/My Drive/MRI_Data/no/No13.jpg
# /content/drive/My Drive/MRI_Data/no/no 95.jpg
# /content/drive/My Drive/MRI_Data/no/no 94.jpg
# /content/drive/My Drive/MRI_Data/no/no 923.jpg
# /content/drive/My Drive/MRI_Data/no/no 89.jpg
# /content/drive/My Drive/MRI_Data/no/no 9.png
# /content/drive/My Drive/MRI_Data/no/no 90.jpg
# /content/drive/My Drive/MRI_Data/no/no 8.jpg
# /content/drive/My Drive/MRI_Data/no/no 92.jpg
# /content/drive/My Drive/MRI_Data/no/no 4.jpg
# /content/drive/My Drive/MRI_Data/no/no 6.jpg
# /content/drive/My Drive/MRI_Data/no/no 7.jpeg
# /content/drive/My Drive/MRI_Data/no/no 91.jpeg
# /content/drive/My Drive/MRI_Data/no/no 5.jpeg
# /content/drive/My Drive/MRI_Data/no/no 3.jpg
# /content/drive/My Drive/MRI_Data/no/no 2.jpg
# /content/drive/My Drive/MRI_Data/no/N3.jpg
# /content/drive/My Drive/MRI_Data/no/N5.jpg
# /content/drive/My Drive/MRI_Data/no/N6.jpg
# /content/drive/My Drive/MRI_Data/no/no 1.jpg
# /content/drive/My Drive/MRI_Data/no/N26.JPG
# /content/drive/My Drive/MRI_Data/no/no 100.jpg
# /content/drive/My Drive/MRI_Data/no/N21.jpg
# /content/drive/My Drive/MRI_Data/no/N22.JPG
# /content/drive/My Drive/MRI_Data/no/N20.JPG
# /content/drive/My Drive/MRI_Data/no/no 10.jpg
# /content/drive/My Drive/MRI_Data/no/N2.JPG
# /content/drive/My Drive/MRI_Data/no/N19.JPG
# /content/drive/My Drive/MRI_Data/no/9 no.jpg
# /content/drive/My Drive/MRI_Data/no/N15.jpg
# /content/drive/My Drive/MRI_Data/no/N11.jpg
# /content/drive/My Drive/MRI_Data/no/N16.jpg
# /content/drive/My Drive/MRI_Data/no/N1.JPG
# /content/drive/My Drive/MRI_Data/no/6 no.jpg
# /content/drive/My Drive/MRI_Data/no/7 no.jpg
# /content/drive/My Drive/MRI_Data/no/8 no.jpg
# /content/drive/My Drive/MRI_Data/no/N17.jpg
# /content/drive/My Drive/MRI_Data/no/50 no.jpg
# /content/drive/My Drive/MRI_Data/no/5 no.jpg
# /content/drive/My Drive/MRI_Data/no/42 no.jpg
# /content/drive/My Drive/MRI_Data/no/41 no.jpg
# /content/drive/My Drive/MRI_Data/no/44no.jpg
# /content/drive/My Drive/MRI_Data/no/43 no.jpg
# /content/drive/My Drive/MRI_Data/no/45 no.jpg
# /content/drive/My Drive/MRI_Data/no/46 no.jpg
# /content/drive/My Drive/MRI_Data/no/47 no.jpg
# /content/drive/My Drive/MRI_Data/no/40 no.jpg
# /content/drive/My Drive/MRI_Data/no/49 no.jpg
# /content/drive/My Drive/MRI_Data/no/48 no.jpeg
# /content/drive/My Drive/MRI_Data/no/4 no.jpg
# /content/drive/My Drive/MRI_Data/no/39 no.jpg
# /content/drive/My Drive/MRI_Data/no/35 no.jpg
# /content/drive/My Drive/MRI_Data/no/36 no.jpg
# /content/drive/My Drive/MRI_Data/no/33 no.jpg
# /content/drive/My Drive/MRI_Data/no/38 no.jpg
# Elapsed time: 0:4:54.2

# %%
def data_summary(main_path):
    
    yes_path = main_path+'yes'
    no_path = main_path+'no'
        
    # number of files (images) that are in the the folder named 'yes' that represent tumorous (positive) examples
    m_pos = len(listdir(yes_path))
    # number of files (images) that are in the the folder named 'no' that represent non-tumorous (negative) examples
    m_neg = len(listdir(no_path))
    # number of all examples
    m = (m_pos+m_neg)
    
    pos_prec = (m_pos* 100.0)/ m
    neg_prec = (m_neg* 100.0)/ m
    
    print(f"Number of examples: {m}")
    print(f"Percentage of positive examples: {pos_prec}%, number of pos examples: {m_pos}") 
    print(f"Percentage of negative examples: {neg_prec}%, number of neg examples: {m_neg}")

# %%
data_summary(augmented_data_path)
# Out:
# Number of examples: 2065
# Percentage of positive examples: 52.54237288135593%, number of pos examples: 1085
# Percentage of negative examples: 47.45762711864407%, number of neg examples: 980

# %% [markdown]
# we will now use this augmented data to train the model.
